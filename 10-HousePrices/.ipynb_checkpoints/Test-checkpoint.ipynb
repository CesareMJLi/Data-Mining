# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
from scipy import stats
from scipy.stats import skew
from scipy.stats import norm
from scipy.stats.stats import pearsonr

# %config InlineBackend.figure_format = 'retina' #set 'png' here when working on notebook
# %matplotlib inline

# %%
train = pd.read_csv("HousePricesTrain.csv")
test = pd.read_csv("HousePricesTest.csv")

# %%
train.describe()
# the train set cover the data 1-1460

# the describe can only describe the numerical values
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  1460.000000  1460.000000  1201.000000    1460.000000  1460.000000
# mean    730.500000    56.897260    70.049958   10516.828082     6.099315
# std     421.610009    42.300571    24.284752    9981.264932     1.382997
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     365.750000    20.000000    59.000000    7553.500000     5.000000
# 50%     730.500000    50.000000    69.000000    9478.500000     6.000000
# 75%    1095.250000    70.000000    80.000000   11601.500000     7.000000
# max    1460.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1460.000000  1460.000000   1460.000000  1452.000000  1460.000000
# mean      5.575342  1971.267808   1984.865753   103.685262   443.639726
# std       1.112799    30.202904     20.645407   181.066207   456.098091
# ...

# %%
train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities    ...     PoolArea PoolQC Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 1         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 2         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 3         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
# 4         Lvl    AllPub    ...            0    NaN   NaN         NaN       0
#
#   MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
test.describe()
# the test data cover the data from 1461-2919 without last column
# Out:
#                 Id   MSSubClass  LotFrontage       LotArea  OverallQual  \
# count  1459.000000  1459.000000  1232.000000   1459.000000  1459.000000
# mean   2190.000000    57.378341    68.580357   9819.161069     6.078821
# std     421.321334    42.746880    22.376841   4955.517327     1.436812
# min    1461.000000    20.000000    21.000000   1470.000000     1.000000
# 25%    1825.500000    20.000000    58.000000   7391.000000     5.000000
# 50%    2190.000000    50.000000    67.000000   9399.000000     6.000000
# 75%    2554.500000    70.000000    80.000000  11517.500000     7.000000
# max    2919.000000   190.000000   200.000000  56600.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  1459.000000  1459.000000   1459.000000  1444.000000  1458.000000
# mean      5.553804  1971.357779   1983.662783   100.709141   439.203704
# std       1.113740    30.390071     21.130467   177.625900   455.268042
# ...

# %%
#train.loc[:,'MSSubClass':'SaleCondition']
#pandas.DataFrame.loc[] select cerntain data
# here we drop the first column "ID" and last column "SALE PRICE"
# select the columns between MSSC and SC now the table have 79 columns

# %%
all_data = pd.concat((train.loc[:,'MSSubClass':'SaleCondition'],
                      test.loc[:,'MSSubClass':'SaleCondition']))

# all_data.head()

# we have all the train and test of certain slice connect together now the table is 2979*79

# %%
matplotlib.rcParams['figure.figsize'] = (10.0, 8.0)
# 10.0*8.0 is the x-axis*y-axis
# sns.distplot(train['SalePrice'])

sns.distplot(train['SalePrice'] , fit=norm)
# fin=norm is a optional paramter, it could generate a approximate of norm distr of given data
# sns generate a diagram

(mu, sigma) = norm.fit(train['SalePrice'])

print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
print("Skewness: %f" % train['SalePrice'].skew())
print("Kurtosis: %f" % train['SalePrice'].kurt())

plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],
            loc='upper right')
# plt.lwgend add a sample on the diagram
# loc is the location of the legend
#     right
# 	center left
# 	upper right
# 	lower right
# 	best
# 	center
# 	lower left
# 	center right
# 	upper left
# 	upper center
# 	lower center
plt.ylabel('Frequency')
plt.title('SalePrice distribution')
# Out:
#  mu = 180921.20 and sigma = 79415.29
#
# Skewness: 1.882876
# Kurtosis: 6.536282
# Text(0.5,1,u'SalePrice distribution')

# %%
train["SalePrice"].describe()
# Out:
# count      1460.000000
# mean     180921.195890
# std       79442.502883
# min       34900.000000
# 25%      129975.000000
# 50%      163000.000000
# 75%      214000.000000
# max      755000.000000
# Name: SalePrice, dtype: float64

# %%
# SalePrice has a skewed distribution. We can make SalePrice more normal by by 
# taking log(SalePrice + 1) and this is generally a good practise.

#We use the numpy fuction log1p which  applies log(1+x) to all elements of the column
train["SalePrice"] = np.log1p(train["SalePrice"])

train["SalePrice"].describe()
# Out:
# count    1460.000000
# mean       12.024057
# std         0.399449
# min        10.460271
# 25%        11.775105
# 50%        12.001512
# 75%        12.273736
# max        13.534474
# Name: SalePrice, dtype: float64

# %%
(mu, sigma) = norm.fit(train['SalePrice'])
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mu, sigma))
print("Skewness: %f" % train['SalePrice'].skew())
print("Kurtosis: %f" % train['SalePrice'].kurt())
# Out:
#  mu = 12.02 and sigma = 0.40
#
# Skewness: 0.121347
# Kurtosis: 0.809519

# %%
matplotlib.rcParams['figure.figsize'] = (8.0, 6.0)
sns.distplot(train['SalePrice'] , fit=norm)
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mu, sigma)],loc='best')
plt.ylabel('Frequency')
plt.title('SalePrice distribution')
# Out:
# Text(0.5,1,u'SalePrice distribution')

# %%
print "the length of all the data is %i" % len(all_data)
#print "the length of all the null data is %i" % all_data.isnull().sum()
#the above line could trigger an error that all_data.isnull().sum() returns a series of values

# print all_data.isnull().sum()
# this line return the null value for each column

all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
# here is the empty value for all data (connection of both train and test)

# print all_data_na
#the above line would return a series of values, each row is a column with their percentage of null value

all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
#print all_data_na
#the above line drop all the values that does not have a null value, and sort in a decreasing order
# Out:
# the length of all the data is 2919

# %%
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
# here we declare a new data frame each line is a column name and each line is a 
missing_data.describe()
# Out:
#        Missing Ratio
# count      30.000000
# mean       15.942674
# std        31.943256
# min         0.034258
# 25%         0.068517
# 50%         2.723535
# 75%         5.447071
# max        99.657417

# %%
f, ax = plt.subplots(figsize=(8,6))

plt.xticks(rotation='90')
#the above line rotate each feature of x 90 degree

sns.barplot(x=all_data_na.index[:10], y=all_data_na[:10])
plt.xlabel('Features', fontsize=15)
plt.ylabel('Percent of Missing Values', fontsize=15)
plt.title('Top Variables for % of Missing Values', fontsize=15)
# Out:
# Text(0.5,1,u'Top Variables for % of Missing Values')

# %%
# fill in the blank

alley_null = ((all_data.isnull().sum() / len(all_data))*100)["Alley"]

print alley_null
# Out:
# 93.21685508735868

# %%
all_data["Alley"] = all_data["Alley"].fillna("None")

alley_null = ((all_data.isnull().sum() / len(all_data))*100)["Alley"]

print alley_null
# Out:
# 0.0

# %%
# for all basement features a missing value means that there is no basement
for col in ('BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2'):
    all_data[col] = all_data[col].fillna('None')

all_data["FireplaceQu"] = all_data["FireplaceQu"].fillna("None")

all_data["Functional"] = all_data["Functional"].fillna("Typ")

for col in ('GarageType', 'GarageFinish', 'GarageQual', 'GarageCond'):
    all_data[col] = all_data[col].fillna('None')

all_data["PoolQC"] = all_data["PoolQC"].fillna("None")

all_data["Fence"] = all_data["Fence"].fillna("None")

all_data["MiscFeature"] = all_data["MiscFeature"].fillna("None")

# %%
all_data["LotFrontage"] = all_data.groupby("Neighborhood")["LotFrontage"].transform(
    lambda x: x.fillna(x.median()))

lotf_null = ((all_data.isnull().sum() / len(all_data))*100)["LotFrontage"]

print lotf_null
# Out:
# 0.0

# %%
for col in ('GarageYrBlt', 'GarageArea', 'GarageCars'):
    all_data[col] = all_data[col].fillna(0)
    
for col in ('BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath'):
    all_data[col] = all_data[col].fillna(0)
    
all_data["MasVnrType"] = all_data["MasVnrType"].fillna("None")
all_data["MasVnrArea"] = all_data["MasVnrArea"].fillna(0)

all_data['MSZoning'] = all_data['MSZoning'].fillna(all_data['MSZoning'].mode()[0])

all_data = all_data.drop(['Utilities'], axis=1)

print all_data['KitchenQual'].mode()[0]
all_data['KitchenQual'] = all_data['KitchenQual'].fillna(all_data['KitchenQual'].mode()[0])
# Out:
# TA

# %%
all_data['SaleType'] = all_data['SaleType'].fillna(all_data['SaleType'].mode()[0])

all_data['MSSubClass'] = all_data['MSSubClass'].fillna("None")

all_data['Electrical'] = all_data['Electrical'].fillna(all_data['Electrical'].mode()[0])

all_data['Exterior1st'] = all_data['Exterior1st'].fillna(all_data['Exterior1st'].mode()[0])
all_data['Exterior2nd'] = all_data['Exterior2nd'].fillna(all_data['Exterior2nd'].mode()[0])

# %%
all_data_na = (all_data.isnull().sum() / len(all_data)) * 100
all_data_na = all_data_na.drop(all_data_na[all_data_na == 0].index).sort_values(ascending=False)[:30]
missing_data = pd.DataFrame({'Missing Ratio' :all_data_na})
missing_data.head(10)
# Out:
# Empty DataFrame
# Columns: [Missing Ratio]
# Index: []

# %%
# take the numerical features
numeric_feats = all_data.dtypes[all_data.dtypes!= "object"].index


print "we have %i features in this situation" % len(numeric_feats)

print numeric_feats

# compute the skewness but only for non missing variables (we already imputed them but just in case ...)
skewed_feats = train[numeric_feats].apply(lambda x: skew(x.dropna()))

skewness = pd.DataFrame({"Variable":skewed_feats.index, "Skewness":skewed_feats.data})
# select the variables with a skewness above a certain threshold
# Out:
# we have 36 features in this situation
# Index([u'MSSubClass', u'LotFrontage', u'LotArea', u'OverallQual',
#        u'OverallCond', u'YearBuilt', u'YearRemodAdd', u'MasVnrArea',
#        u'BsmtFinSF1', u'BsmtFinSF2', u'BsmtUnfSF', u'TotalBsmtSF', u'1stFlrSF',
#        u'2ndFlrSF', u'LowQualFinSF', u'GrLivArea', u'BsmtFullBath',
#        u'BsmtHalfBath', u'FullBath', u'HalfBath', u'BedroomAbvGr',
#        u'KitchenAbvGr', u'TotRmsAbvGrd', u'Fireplaces', u'GarageYrBlt',
#        u'GarageCars', u'GarageArea', u'WoodDeckSF', u'OpenPorchSF',
#        u'EnclosedPorch', u'3SsnPorch', u'ScreenPorch', u'PoolArea', u'MiscVal',
#        u'MoSold', u'YrSold'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-a7fc51b61101> in <module>()
#      10 skewed_feats = train[numeric_feats].apply(lambda x: skew(x.dropna()))
#      11
# ...
